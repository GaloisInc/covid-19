# %%
import pandas as pd
import matplotlib.pyplot as plt

us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    'Guam' : 'GM'
}

ventilatorsPerState = pd.read_csv('ventilators.csv', index_col=0)
bedsPerState = pd.read_csv('hospitals_beds.csv', index_col=0).groupby(['State']).sum().reset_index()

ventilatorsPerState['State'] = ventilatorsPerState['State'].apply(lambda x: us_state_abbrev[x])

hospitalResources = ventilatorsPerState.join(bedsPerState.set_index('State'), on='State')

hospitalResources['Ventilators/Bed'] = hospitalResources.apply(lambda x: x['Ventilators']/x['Beds'], axis=1)

ax = hospitalResources.plot.scatter(x='Beds', y='Ventilators', alpha=0.5, figsize=(20,10))
for i, txt in enumerate(hospitalResources.State):
    ax.annotate(txt, (hospitalResources.Beds.iat[i],hospitalResources.Ventilators.iat[i]))
plt.show()

# %%
hospitalProfiles = pd.read_csv('hospitals_beds.csv', index_col=0)

# %%
import requests

URL = 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population'

r = requests.get(URL)

stateStats = pd.read_html(r.content, header=[0])[0]
stateStats.columns = ['Drop0', 'Drop1', 'State', 'Population', 'Drop2', 'Drop3', 'Drop4', 'Drop5', 'Drop6', 'Drop7', 'Drop8', 'Drop9']
stateStats = stateStats[['State', 'Population']].iloc[1:53]
stateStats['State'] = stateStats['State'].apply(lambda x: us_state_abbrev[x])
stateStats['Population'] = stateStats['Population'].apply(lambda x: int(x))

perCapitaResources = hospitalResources.join(stateStats.set_index('State'), on='State')
perCapitaResources['Beds/100,000'] = perCapitaResources.apply(lambda x: x['Beds']/x['Population'], axis = 1) * 100000
perCapitaResources['Ventilators/100,000'] = perCapitaResources.apply(lambda x: x['Ventilators']/x['Population'], axis = 1) * 100000

perCapitaResources

ax = perCapitaResources.plot.scatter(x='Beds/100,000', y='Ventilators/100,000', alpha=0.5, figsize=(20,10))
for i, txt in enumerate(perCapitaResources.State):
    ax.annotate(txt, (perCapitaResources['Beds/100,000'].iat[i],perCapitaResources['Ventilators/100,000'].iat[i]))
plt.show()

# %%
def calcVentilators(row):
    beds = float(row['Beds'])
    state = row['State']
    ventilators = 0.0
    try:
        vpb = float(perCapitaResources[perCapitaResources['State'].str.contains(state)]['Ventilators/Bed'])
        ventilators = beds * vpb
    except:
        return ventilators        
    return ventilators

def vpbLookup(row):
    state = row['State']
    vpb = 0.0
    try:
        vpb = float(perCapitaResources[perCapitaResources['State'].str.contains(state)]['Ventilators/Bed'])
    except:
        return vpb
    return vpb

    
hospitalProfiles['Estimated Ventilators'] = hospitalProfiles.apply(calcVentilators, axis=1)
hospitalProfiles['Statewide Ventilators per Bed'] = hospitalProfiles.apply(vpbLookup, axis=1)
hospitalProfiles.to_csv('hospital_profiles.csv')

# %%
hospitalProfiles
# Out:
#                                           Hospital Name  Beds  \
# 0                    Northside Behavioral Health Center     0
# 1     Adventist Health Saint Helena Center for Behav...    61
# 2                          Adventist Health Simi Valley   144
# 3                                Adventist Ukiah Valley    50
# 4      Ascension Columbia Saint Mary's Hospital Ozaukee   120
# 5      Ascension Columbia Saint Mary's Women's Hospital     0
# 6                Ascension Our Lady of Victory Hospital    24
# 7                         Ascension Saint John Hospital   612
# 8                    Ascension Saint Michael's Hospital    84
# 9                    Avera Dakota Plains Surgery Center    15
# 10            Baylor Scott & White Medical Center Plano   118
# 11        Baylor Scott & White Medical Center Grapevine   289
# 12           Baylor Scott & White Medical Center Temple   634
# 13                                    Brockton Hospital   197
# 14    California Department of State Hospitals - Coa...     0
# 15      California Department of State Hospitals - Napa    49
# 16    California Department of State Hospitals Salin...     0
# 17                     Carle Richland Memorial Hospital    81
# 18                              Chester County Hospital   244
# 19                    CHI Memorial Hospital Chattanooga   423
# 20                           CHI Saint Anthony Hospital    25
# 21     CHI Saint Joseph Health Continuing Care Hospital    23
# 22             CHI St. Joseph Health Bellville Hospital    32
# 23     CHRISTUS Good Shepherd Medical Center - Marshall   361
# 24       CHRISTUS Good Shepherd Medical Center Longview   351
# 25                              Cuero Regional Hospital    44
# 26                                  Daniel Drake Center   211
# 27                                Downey Medical Center   352
# 28                            Emory Hillandale Hospital    90
# 29    Encompass Health Rehabilitation Hospital of Miami    60
# ...                                                 ...   ...
# 6998             Worcester Recovery Center and Hospital   290
# 6999                            Wrangell Medical Center    22
# 7000                   Wray Community District Hospital    16
# 7001                           Wright Memorial Hospital    21
# 7002                   WVU Medicine Children's Hospital     0
# 7003                          Wyandot Memorial Hospital    24
# 7004                     Wyckoff Heights Medical Center   257
# 7005                       Wyoming Behavioral Institute    81
# 7006             Wyoming County Community Health System   200
# 7007                             Wyoming Medical Center   212
# 7008                             Wyoming State Hospital    73
# 7009                    Wythe County Community Hospital   100
# 7010                 Yale-New Haven Children's Hospital     0
# 7011                            Yale-New Haven Hospital  1540
# 7012       Yale-New Haven Hospital Saint Raphael Campus   573
# 7013                Yale-New Haven Psychiatric Hospital     0
# 7014                         Yalobusha General Hospital    26
# 7015             Yavapai Regional Medical Center - East    56
# 7016             Yavapai Regional Medical Center - West   206
# 7017                          Yoakum Community Hospital    25
# 7018                             Yoakum County Hospital    24
# 7019                              York General Hospital   154
# 7020                                      York Hospital    66
# 7021            Yukon-Kuskokwim Delta Regional Hospital    34
# 7022                             Yuma District Hospital    15
# 7023                       Yuma Regional Medical Center   406
# 7024  Yuma Rehabilitation Hospital, an affiliation o...    51
# 7025  Zale Lipshy Pavilion-William P. Clements Jr. U...   148
# 7026  Zuckerberg San Francisco General Hospital and ...   397
# 7027                                      Zuni Hospital    27
#
#                  City State  Estimated Ventilators  \
# 0               Tampa    FL               0.000000
# 1             Vallejo    CA               4.760613
# 2         Simi Valley    CA              11.238167
# 3               Ukiah    CA               3.902141
# 4              Mequon    WI               6.831840
# 5           Milwaukee    WI               0.000000
# 6             Stanley    WI               1.366368
# 7             Detroit    MI              40.115125
# 8       Stevens Point    WI               4.782288
# 9            Aberdeen    SD               0.537001
# 10              Plano    TX               8.401550
# 11          Grapevine    TX              20.576678
# 12             Temple    TX              45.140533
# 13           Brockton    MA              13.582215
# 14           Coalinga    CA               0.000000
# 15               Napa    CA               3.824099
# 16            Soledad    CA               0.000000
# 17              Olney    IL               5.493177
# 18       West Chester    PA              17.234498
# 19        Chattanooga    TN              29.873883
# 20          Pendleton    OR               1.682274
# 21          Lexington    KY               1.315593
# 22          Bellville    TX               2.278387
# 23           Marshall    TX              25.703048
# 24           Longview    TX              24.991052
# 25              Cuero    TX               3.132782
# 26         Cincinnati    OH              16.255971
# 27             Downey    CA              27.471076
# 28           Lithonia    GA               6.803308
# 29              Miami    FL               4.142740
# ...               ...   ...                    ...
# 6998        Worcester    MA              19.994124
# 6999         Wrangell    AK               1.286839
# 7000             Wray    CO               1.219162
# 7001          Trenton    MO               1.464619
# 7002       Morgantown    WV               0.000000
# 7003   Upper Sandusky    OH               1.849020
# 7004         Brooklyn    NY              18.098931
# 7005           Casper    WY               4.290177
# 7006           Warsaw    NY              14.084771
# 7007           Casper    WY              11.228610
# 7008         Evanston    WY               3.866455
# 7009       Wytheville    VA               6.644088
# 7010        New Haven    CT               0.000000
# 7011        New Haven    CT             103.509183
# 7012        New Haven    CT              38.513482
# 7013        New Haven    CT               0.000000
# 7014     Water Valley    MS               1.701472
# 7015  Prescott Valley    AZ               4.480685
# 7016         Prescott    AZ              16.482518
# 7017           Yoakum    TX               1.779989
# 7018      Denver City    TX               1.708790
# 7019             York    NE              10.042541
# 7020             York    ME               3.780514
# 7021           Bethel    AK               1.988751
# 7022             Yuma    CO               1.142964
# 7023             Yuma    AZ              32.484963
# 7024             Yuma    AZ               4.080623
# 7025           Dallas    TX              10.537538
# 7026    San Francisco    CA              30.983003
# 7027             Zuni    NM               2.040050
#
#       Statewide Ventilators per Bed
# 0                          0.069046
# 1                          0.078043
# 2                          0.078043
# 3                          0.078043
# 4                          0.056932
# 5                          0.056932
# 6                          0.056932
# 7                          0.065548
# 8                          0.056932
# 9                          0.035800
# 10                         0.071200
# 11                         0.071200
# 12                         0.071200
# 13                         0.068945
# 14                         0.078043
# 15                         0.078043
# 16                         0.078043
# 17                         0.067817
# 18                         0.070633
# 19                         0.070624
# 20                         0.067291
# 21                         0.057200
# 22                         0.071200
# 23                         0.071200
# 24                         0.071200
# 25                         0.071200
# 26                         0.077043
# 27                         0.078043
# 28                         0.075592
# 29                         0.069046
# ...                             ...
# 6998                       0.068945
# 6999                       0.058493
# 7000                       0.076198
# 7001                       0.069744
# 7002                       0.073275
# 7003                       0.077043
# 7004                       0.070424
# 7005                       0.052965
# 7006                       0.070424
# 7007                       0.052965
# 7008                       0.052965
# 7009                       0.066441
# 7010                       0.067214
# 7011                       0.067214
# 7012                       0.067214
# 7013                       0.067214
# 7014                       0.065441
# 7015                       0.080012
# 7016                       0.080012
# 7017                       0.071200
# 7018                       0.071200
# 7019                       0.065211
# 7020                       0.057281
# 7021                       0.058493
# 7022                       0.076198
# 7023                       0.080012
# 7024                       0.080012
# 7025                       0.071200
# 7026                       0.078043
# 7027                       0.075557
#
# [7028 rows x 6 columns]

# %%
df = pd.read_csv('hospitals_beds.csv', index_col=0)

df[df['State'].str.contains('OR')][df['City'].str.contains('Medford')]

df['City, State'] = df['City'] + ', ' + df['State']
df['City, State'].unique().shape
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (4129,)
